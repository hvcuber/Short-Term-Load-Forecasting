# %% [markdown]
# <h1><center>Big Data Analytics for Short Term Load Forecasting using Hybrid Artificial Neural Network</center></h1>

# %% [markdown]
# Objective:
#
# The primary role of an electricity distribution utility is to arrange quality power for its licensed registered consumer and distribute uninterrupted power to them. Power Management function encompasses arrangement of power for the distribution companies predicting the future demand.

# %% [markdown]
# # Import Libraries

# %%
#pip install numpy==1.26.4 scipy==1.14.1 matplotlib==3.8.4 scikit-learn==1.5.1 pandas==2.2.2 statsmodels==0.14.2 holidays --break-system-packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import datetime
from datetime import date
import holidays
import pickle
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib import rcParams
plt.style.use('bmh') 
# Above is a special style template for matplotlib, highly useful for visualizing time series data
# %matplotlib inline
from pylab import rcParams
import statsmodels.api as sm

from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, Bidirectional, TimeDistributed
from tensorflow.keras.layers import MaxPooling1D, Flatten
from tensorflow.keras.metrics import RootMeanSquaredError
from keras.metrics import MeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError
from tensorflow.keras.utils import plot_model
from tensorflow.keras.regularizers import L1
from sklearn.metrics import r2_score, explained_variance_score

from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

warnings.filterwarnings("ignore")

# %%
#pip install numpy scipy matplotlib scikit-learn pandas statsmodels seaborn holidays tensorflow Jinja2 --break-system-packages

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Two distinct datasets were utilised for short-term load forecasting.
#
# 1. Load Dataset (2017 - 2019)
# 2. Weather Dataset (2017-2019)

# %% [markdown]
# ## Load Data Preprocessing

# %%
load_data = pd.read_excel("2017-2022.xlsx", sheet_name="Sheet1")
load_data
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[210], line 1
# ----> 1 load_data = pd.read_excel("2017-2022.xlsx", sheet_name="Sheet1")
#       2 load_data
#
# File c:\Python\Python3.13\Lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#     507 try:
# --> 508     data = io.parse(
#     509         sheet_name=sheet_name,
#     510         header=header,
#     511         names=names,
#     512         index_col=index_col,
#     513         usecols=usecols,
#     514         dtype=dtype,
#     515         converters=converters,
#     516         true_values=true_values,
#     517         false_values=false_values,
#     518         skiprows=skiprows,
#     519         nrows=nrows,
#     520         na_values=na_values,
#     521         keep_default_na=keep_default_na,
#     522         na_filter=na_filter,
#     523         verbose=verbose,
#     524         parse_dates=parse_dates,
#     525         date_parser=date_parser,
#     526         date_format=date_format,
#     527         thousands=thousands,
#     528         decimal=decimal,
#     529         comment=comment,
#     530         skipfooter=skipfooter,
#     531         dtype_backend=dtype_backend,
#     532     )
#     533 finally:
#     534     # make sure to close opened file handles
#     535     if should_close:
#
# File c:\Python\Python3.13\Lib\site-packages\pandas\io\excel\_base.py:1616, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, date_format, thousands, comment, skipfooter, dtype_backend, **kwds)
#    1576 def parse(
#    1577     self,
#    1578     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)   1596     **kwds,
#    1597 ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    1598     """
#    1599     Parse specified sheet(s) into a DataFrame.
#    1600
#    (...)   1614     >>> file.parse()  # doctest: +SKIP
#    1615     """
# -> 1616     return self._reader.parse(
#    1617         sheet_name=sheet_name,
#    1618         header=header,
#    1619         names=names,
#    1620         index_col=index_col,
#    1621         usecols=usecols,
#    1622         converters=converters,
#    1623         true_values=true_values,
#    1624         false_values=false_values,
#    1625         skiprows=skiprows,
#    1626         nrows=nrows,
#    1627         na_values=na_values,
#    1628         parse_dates=parse_dates,
#    1629         date_parser=date_parser,
#    1630         date_format=date_format,
#    1631         thousands=thousands,
#    1632         comment=comment,
#    1633         skipfooter=skipfooter,
#    1634         dtype_backend=dtype_backend,
#    1635         **kwds,
#    1636     )
#
# File c:\Python\Python3.13\Lib\site-packages\pandas\io\excel\_base.py:778, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, dtype_backend, **kwds)
#     775     sheet = self.get_sheet_by_index(asheetname)
#     777 file_rows_needed = self._calc_rows(header, index_col, skiprows, nrows)
# --> 778 data = self.get_sheet_data(sheet, file_rows_needed)
#     779 if hasattr(sheet, "close"):
#     780     # pyxlsb opens two TemporaryFiles
#     781     sheet.close()
#
# File c:\Python\Python3.13\Lib\site-packages\pandas\io\excel\_openpyxl.py:615, in OpenpyxlReader.get_sheet_data(self, sheet, file_rows_needed)
#     613 data: list[list[Scalar]] = []
#     614 last_row_with_data = -1
# --> 615 for row_number, row in enumerate(sheet.rows):
#     616     converted_row = [self._convert_cell(cell) for cell in row]
#     617     while converted_row and converted_row[-1] == "":
#     618         # trim trailing empty elements
#
# File c:\Python\Python3.13\Lib\site-packages\openpyxl\worksheet\_read_only.py:85, in ReadOnlyWorksheet._cells_by_row(self, min_col, min_row, max_col, max_row, values_only)
#      77 with self._get_source() as src:
#      78     parser = WorkSheetParser(src,
#      79                              self._shared_strings,
#      80                              data_only=self.parent.data_only,
#      81                              epoch=self.parent.epoch,
#      82                              date_formats=self.parent._date_formats,
#      83                              timedelta_formats=self.parent._timedelta_formats)
# ---> 85     for idx, row in parser.parse():
#      86         if max_row is not None and idx > max_row:
#      87             break
#
# File c:\Python\Python3.13\Lib\site-packages\openpyxl\worksheet\_reader.py:156, in WorkSheetParser.parse(self)
#     137 properties = {
#     138     PRINT_TAG: ('print_options', PrintOptions),
#     139     MARGINS_TAG: ('page_margins', PageMargins),
#    (...)    151
#     152 }
#     154 it = iterparse(self.source) # add a finaliser to close the source when this becomes possible
# --> 156 for _, element in it:
#     157     tag_name = element.tag
#     158     if tag_name in dispatcher:
#
# File c:\Python\Python3.13\Lib\xml\etree\ElementTree.py:1238, in iterparse.<locals>.iterator(source)
#    1236 yield from pullparser.read_events()
#    1237 # load event buffer
# -> 1238 data = source.read(16 * 1024)
#    1239 if not data:
#    1240     break
#
# File c:\Python\Python3.13\Lib\zipfile\__init__.py:1012, in ZipExtFile.read(self, n)
#    1010 self._offset = 0
#    1011 while n > 0 and not self._eof:
# -> 1012     data = self._read1(n)
#    1013     if n < len(data):
#    1014         self._readbuffer = data
#
# File c:\Python\Python3.13\Lib\zipfile\__init__.py:1080, in ZipExtFile._read1(self, n)
#    1078     data = self._decompressor.unconsumed_tail
#    1079     if n > len(data):
# -> 1080         data += self._read2(n - len(data))
#    1081 else:
#    1082     data = self._read2(n)
#
# File c:\Python\Python3.13\Lib\zipfile\__init__.py:1112, in ZipExtFile._read2(self, n)
#    1109 n = max(n, self.MIN_READ_SIZE)
#    1110 n = min(n, self._compress_left)
# -> 1112 data = self._fileobj.read(n)
#    1113 self._compress_left -= len(data)
#    1114 if not data:
#
# File c:\Python\Python3.13\Lib\zipfile\__init__.py:832, in _SharedFile.read(self, n)
#     830 self._file.seek(self._pos)
#     831 data = self._file.read(n)
# --> 832 self._pos = self._file.tell()
#     833 return data
#
# KeyboardInterrupt:

# %%
load_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204480 entries, 0 to 204479
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   datetime          204480 non-null  object
#  1   demand load       202738 non-null  float64
#  2   sldc load         202738 non-null  float64
#  3   scada load        202738 non-null  float64
#  4   od/ud sldc load   204480 non-null  float64
#  5   od/ud scada load  204480 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 9.4+ MB

# %%
load_data.describe()
# Out:
#          demand load      sldc load     scada load  od/ud sldc load  \
# count  202738.000000  202738.000000  202738.000000    204480.000000
# mean     1543.773984    1534.804437    1517.551100        -8.893134
# std       527.918990     525.863416     531.549262        55.338041
# min       399.000000     400.000000     449.000000      -298.000000
# 25%      1170.000000    1163.000000    1127.000000       -38.000000
# 50%      1496.000000    1483.000000    1473.000000        -7.500000
# 75%      1924.000000    1912.000000    1890.000000        21.000000
# max      3455.000000    3345.000000    3405.000000       299.000000
#
#        od/ud scada load
# count     204480.000000
# mean         -25.999487
# std           79.380589
# min         -299.000000
# 25%          -55.000000
# 50%          -13.000000
# 75%           17.000000
# max          299.000000

# %%
load_data.isnull().sum()
# Out:
# datetime               0
# demand load         1742
# sldc load           1742
# scada load          1742
# od/ud sldc load        0
# od/ud scada load       0
# dtype: int64

# %% [markdown]
# ### To handling the missing value, spline Interpolation is used to estimating unknown data points in a given range.

# %% [markdown]
# ### Interpolation of DEMAND, SLDC and SCADA load data

# %%
load_data['DEMAND LOAD'] = load_data['demand load'].interpolate(option='spline', 
                                                                order=5, 
                                                                limit_direction='both')

load_data['SLDC LOAD'] = load_data['sldc load'].interpolate(option='spline', 
                                                            order=5, 
                                                            limit_direction='both')

load_data['SCADA LOAD'] = load_data['scada load'].interpolate(option='spline', 
                                                              order=5, 
                                                              limit_direction='both')

# %% [markdown]
# ### Description of dataset after interpolation of missing data

# %%
load_data = pd.DataFrame([load_data['datetime'], 
                          load_data['DEMAND LOAD'], 
                          load_data['SLDC LOAD'], 
                          load_data['SCADA LOAD']]).transpose()
load_data
# Out:
#                    datetime DEMAND LOAD SLDC LOAD SCADA LOAD
# 0       01-01-2017 00:00:00       635.0     710.0      756.0
# 1       01-01-2017 00:15:00       730.0     682.0      730.0
# 2       01-01-2017 00:30:00       686.0     660.0      701.0
# 3       01-01-2017 00:45:00       645.0     641.0      674.0
# 4       01-01-2017 01:00:00       628.0     620.0      650.0
# ...                     ...         ...       ...        ...
# 204475  31-10-2022 22:45:00      1053.0    1032.0     1032.0
# 204476  31-10-2022 23:00:00      1039.0    1008.0     1007.0
# 204477  31-10-2022 23:15:00      1013.0     984.0      982.0
# 204478  31-10-2022 23:30:00       963.0     957.0      957.0
# 204479  31-10-2022 23:45:00       969.0     936.0      933.0
#
# [204480 rows x 4 columns]

# %%
load_data.isnull().sum()
# Out:
# datetime       0
# DEMAND LOAD    0
# SLDC LOAD      0
# SCADA LOAD     0
# dtype: int64

# %% [markdown]
# ### Load Dataset

# %%
final_load_dataset = pd.DataFrame([load_data['DEMAND LOAD'], 
                                   load_data['SLDC LOAD'], 
                                   load_data['SCADA LOAD']]).transpose()

final_load_dataset.index = pd.to_datetime(load_data['datetime'].astype(str),format='%d-%m-%Y %H:%M:%S') 
final_load_dataset = final_load_dataset.rename_axis('datetime').reset_index()
final_load_dataset
# Out:
#                   datetime  DEMAND LOAD  SLDC LOAD  SCADA LOAD
# 0      2017-01-01 00:00:00        635.0      710.0       756.0
# 1      2017-01-01 00:15:00        730.0      682.0       730.0
# 2      2017-01-01 00:30:00        686.0      660.0       701.0
# 3      2017-01-01 00:45:00        645.0      641.0       674.0
# 4      2017-01-01 01:00:00        628.0      620.0       650.0
# ...                    ...          ...        ...         ...
# 204475 2022-10-31 22:45:00       1053.0     1032.0      1032.0
# 204476 2022-10-31 23:00:00       1039.0     1008.0      1007.0
# 204477 2022-10-31 23:15:00       1013.0      984.0       982.0
# 204478 2022-10-31 23:30:00        963.0      957.0       957.0
# 204479 2022-10-31 23:45:00        969.0      936.0       933.0
#
# [204480 rows x 4 columns]

# %%
final_load_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204480 entries, 0 to 204479
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   datetime     204480 non-null  datetime64[ns]
#  1   DEMAND LOAD  204480 non-null  float64
#  2   SLDC LOAD    204480 non-null  float64
#  3   SCADA LOAD   204480 non-null  float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 6.2 MB

# %%
final_load_dataset.describe()
# Out:
#                             datetime    DEMAND LOAD      SLDC LOAD  \
# count                         204480  204480.000000  204480.000000
# mean   2019-12-02 00:00:31.690141184    1543.867527    1534.892163
# min              2017-01-01 00:00:00     399.000000     400.000000
# 25%              2018-06-17 11:56:15    1170.000000    1163.000000
# 50%              2019-12-01 23:52:30    1497.000000    1485.000000
# 75%              2021-05-17 11:48:45    1924.000000    1912.000000
# max              2022-10-31 23:45:00    3455.000000    3345.000000
# std                              NaN     527.497234     525.373783
#
#           SCADA LOAD
# count  204480.000000
# mean     1517.803775
# min       449.000000
# 25%      1127.000000
# 50%      1475.000000
# 75%      1890.000000
# max      3405.000000
# std       531.071648

# %% [markdown]
# ## Weather Data Preprocessing

# %%
weather_data = pd.read_csv("2017-01-01 to 2022-10-31.csv")
weather_data.head()
# Out:
#                                                 name             datetime  \
# 0  G7R6 P5G, Balaji Estate, Kalkaji, New Delhi, D...  2017-01-01T00:00:00
# 1  G7R6 P5G, Balaji Estate, Kalkaji, New Delhi, D...  2017-01-01T01:00:00
# 2  G7R6 P5G, Balaji Estate, Kalkaji, New Delhi, D...  2017-01-01T02:00:00
# 3  G7R6 P5G, Balaji Estate, Kalkaji, New Delhi, D...  2017-01-01T03:00:00
# 4  G7R6 P5G, Balaji Estate, Kalkaji, New Delhi, D...  2017-01-01T04:00:00
#
#    temp  feelslike   dew  humidity  precip  precipprob preciptype  snow  ...  \
# 0  13.0       13.0  12.0     93.65     0.0           0        NaN   0.0  ...
# 1  13.0       13.0  12.0     93.65     0.0           0        NaN   0.0  ...
# 2  12.2       12.2  11.7     97.01     0.0           0        NaN   0.0  ...
# 3  12.0       12.0  11.0     93.60     0.0           0        NaN   0.0  ...
# 4  12.0       12.0  11.0     93.60     0.0           0        NaN   0.0  ...
#
#    sealevelpressure  cloudcover  visibility  solarradiation  solarenergy  \
# 0               NaN         0.0         1.0             0.0          NaN
# 1               NaN         0.0         1.0             0.0          NaN
# 2            1016.1         0.0         1.0             0.0          NaN
# 3               NaN         0.0         1.0             0.0          NaN
# 4               NaN         0.0         0.0             0.0          NaN
#
#    uvindex  severerisk  conditions         icon                      stations
# 0      0.0         NaN       Clear  clear-night              VIDP,42181099999
# 1      0.0         NaN       Clear  clear-night              VIDP,42181099999
# 2      0.0         NaN       Clear  clear-night  42182099999,VIDP,42181099999
# 3      0.0         NaN       Clear  clear-night              VIDP,42181099999
# 4      0.0         NaN       Clear  clear-night              VIDP,42181099999
#
# [5 rows x 24 columns]

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51121 entries, 0 to 51120
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              51121 non-null  object
#  1   datetime          51121 non-null  object
#  2   temp              51121 non-null  float64
#  3   feelslike         51121 non-null  float64
#  4   dew               51121 non-null  float64
#  5   humidity          51121 non-null  float64
#  6   precip            51121 non-null  float64
#  7   precipprob        51121 non-null  int64
#  8   preciptype        1257 non-null   object
#  9   snow              50534 non-null  float64
#  10  snowdepth         50534 non-null  float64
#  11  windgust          9068 non-null   float64
#  12  windspeed         51121 non-null  float64
#  13  winddir           51121 non-null  float64
#  14  sealevelpressure  26680 non-null  float64
#  15  cloudcover        51121 non-null  float64
#  16  visibility        50524 non-null  float64
#  17  solarradiation    51095 non-null  float64
#  18  solarenergy       27787 non-null  float64
#  19  uvindex           51095 non-null  float64
#  20  severerisk        7063 non-null   float64
#  21  conditions        51121 non-null  object
#  22  icon              51121 non-null  object
#  23  stations          51121 non-null  object
# dtypes: float64(17), int64(1), object(6)
# memory usage: 9.4+ MB

# %%
weather_data.describe()
# Out:
#                temp     feelslike           dew      humidity        precip  \
# count  51121.000000  51121.000000  51121.000000  51121.000000  51121.000000
# mean      25.533190     27.466933     16.607885     63.499998      0.105216
# std        8.290339     10.285564      6.988801     23.399803      1.615397
# min        0.800000     -1.500000    -11.700000      5.030000      0.000000
# 25%       19.000000     19.000000     11.000000     45.270000      0.000000
# 50%       27.000000     27.800000     15.900000     65.490000      0.000000
# 75%       31.700000     35.600000     23.700000     83.650000      0.000000
# max       47.500000     57.300000     30.000000    100.000000     91.645000
#
#          precipprob     snow  snowdepth     windgust     windspeed  \
# count  51121.000000  50534.0    50534.0  9068.000000  51121.000000
# mean       1.885722      0.0        0.0    20.493913      7.613284
# std       13.602201      0.0        0.0    11.920981      5.812156
# min        0.000000      0.0        0.0     0.700000      0.000000
# 25%        0.000000      0.0        0.0    10.100000      2.800000
# 50%        0.000000      0.0        0.0    18.700000      7.600000
# 75%        0.000000      0.0        0.0    31.700000     11.200000
# max      100.000000      0.0        0.0    85.300000    203.800000
#
#             winddir  sealevelpressure    cloudcover    visibility  \
# count  51121.000000      26680.000000  51121.000000  50524.000000
# mean     163.750204       1007.670165     33.798038      2.739015
# std      118.928169          7.086380     31.939148      1.469905
# min        0.000000        987.700000      0.000000      0.000000
# 25%       55.000000       1002.000000      0.000000      2.000000
# 50%      150.000000       1007.000000     29.000000      2.900000
# 75%      272.000000       1013.800000     54.700000      3.800000
# max      360.000000       1025.600000    100.000000     24.100000
#
#        solarradiation   solarenergy       uvindex   severerisk
# count    51095.000000  27787.000000  51095.000000  7063.000000
# mean       224.453626      1.485284      2.235052    10.371797
# std        301.215982      1.075950      3.028023     4.547519
# min          0.000000      0.000000      0.000000     3.000000
# 25%          0.000000      0.500000      0.000000    10.000000
# 50%         10.500000      1.500000      0.000000    10.000000
# 75%        450.000000      2.400000      5.000000    10.000000
# max       1047.000000      3.800000     10.000000    60.000000

# %% [markdown]
# ### Eliminate the unwanted columns from the weather data and create a dataframe by using temperature and humidity data only.

# %%
hourly_weather_data = pd.DataFrame([weather_data['temp'], 
                                    weather_data['humidity']]).transpose()

hourly_weather_data.index = pd.to_datetime(weather_data['datetime'])
hourly_weather_data
# Out:
#                      temp  humidity
# datetime
# 2017-01-01 00:00:00  13.0     93.65
# 2017-01-01 01:00:00  13.0     93.65
# 2017-01-01 02:00:00  12.2     97.01
# 2017-01-01 03:00:00  12.0     93.60
# 2017-01-01 04:00:00  12.0     93.60
# ...                   ...       ...
# 2022-10-31 20:00:00  22.3     81.54
# 2022-10-31 21:00:00  23.0     64.72
# 2022-10-31 22:00:00  22.0     73.29
# 2022-10-31 23:00:00  20.7     84.41
# 2022-11-01 00:00:00  20.0     82.51
#
# [51121 rows x 2 columns]

# %% [markdown]
# ### Checking for null values in temperature and humidity data

# %%
hourly_weather_data.isnull().sum()
# Out:
# temp        0
# humidity    0
# dtype: int64

# %%
hourly_weather_data.describe()
# Out:
#                temp      humidity
# count  51121.000000  51121.000000
# mean      25.533190     63.499998
# std        8.290339     23.399803
# min        0.800000      5.030000
# 25%       19.000000     45.270000
# 50%       27.000000     65.490000
# 75%       31.700000     83.650000
# max       47.500000    100.000000

# %% [markdown]
# ### Convert the hourly data into 15 minutes slots

# %%
temperature = pd.DataFrame(hourly_weather_data.temp.resample('15Min').mean()).interpolate(method= 'spline', 
                                                                                          order= 5, 
                                                                                          limit_direction= 'both')

humidity = pd.DataFrame(hourly_weather_data.humidity.resample('15Min').mean()).interpolate(method= 'spline', 
                                                                                           order= 5, 
                                                                                           limit_direction= 'both')

# %%
minutes_weather_data = pd.DataFrame([temperature['temp'], humidity['humidity']]).transpose()
minutes_weather_data.reset_index()
minutes_weather_data.head()
# Out:
#                           temp   humidity
# datetime
# 2017-01-01 00:00:00  13.000000  93.650000
# 2017-01-01 00:15:00  12.947809  93.895246
# 2017-01-01 00:30:00  13.016861  94.248682
# 2017-01-01 00:45:00  13.059741  94.521383
# 2017-01-01 01:00:00  13.000000  93.650000

# %%
minutes_weather_data.describe()
# Out:
#                 temp       humidity
# count  204481.000000  204481.000000
# mean       25.533311      63.499588
# std         8.240901      23.338513
# min         0.800000      -6.045923
# 25%        19.260748      45.370000
# 50%        27.089904      65.482395
# 75%        31.558436      83.491145
# max        47.500000     116.175782

# %% [markdown]
# ### Weather Dataset

# %%
final_weather_dataset = pd.DataFrame([minutes_weather_data['temp'], 
                                      minutes_weather_data['humidity']]).transpose().iloc[:-1]

final_weather_dataset = final_weather_dataset.reset_index()
final_weather_dataset.head()
# Out:
#              datetime       temp   humidity
# 0 2017-01-01 00:00:00  13.000000  93.650000
# 1 2017-01-01 00:15:00  12.947809  93.895246
# 2 2017-01-01 00:30:00  13.016861  94.248682
# 3 2017-01-01 00:45:00  13.059741  94.521383
# 4 2017-01-01 01:00:00  13.000000  93.650000

# %%
final_weather_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204480 entries, 0 to 204479
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   datetime  204480 non-null  datetime64[ns]
#  1   temp      204480 non-null  float64
#  2   humidity  204480 non-null  float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 4.7 MB

# %%
final_weather_dataset.describe()
# Out:
#                             datetime           temp       humidity
# count                         204480  204480.000000  204480.000000
# mean   2019-12-01 23:52:30.000000512      25.533338      63.499496
# min              2017-01-01 00:00:00       0.800000      -6.045923
# 25%              2018-06-17 11:56:15      19.260734      45.370000
# 50%              2019-12-01 23:52:30      27.089993      65.481454
# 75%              2021-05-17 11:48:45      31.558437      83.491249
# max              2022-10-31 23:45:00      47.500000     116.175782
# std                              NaN       8.240912      23.338532

# %%
final_weather_dataset.isnull().sum()
# Out:
# datetime    0
# temp        0
# humidity    0
# dtype: int64

# %% [markdown]
# ### Migration of Load and Weather dataset for feature engineering

# %%
final_dataset = pd.DataFrame([final_weather_dataset['temp'], 
                              final_weather_dataset['humidity'],
                              final_load_dataset['DEMAND LOAD'],
                              final_load_dataset['SLDC LOAD'],
                              final_load_dataset['SCADA LOAD']]).transpose()

final_dataset.index = pd.to_datetime(load_data['datetime'].astype(str), format='%d-%m-%Y %H:%M:%S')

final_dataset = final_dataset.rename_axis('DATETIME').reset_index()
final_dataset.columns = ['DATETIME', 'TEMPERATURE', 'HUMIDITY', 'DEMAND LOAD', 'SLDC LOAD', 'SCADA LOAD']
final_dataset = final_dataset[['DATETIME', 'TEMPERATURE', 'HUMIDITY', 'DEMAND LOAD', 'SLDC LOAD', 'SCADA LOAD']]

# %%
final_dataset.head()
# Out:
#              DATETIME  TEMPERATURE   HUMIDITY  DEMAND LOAD  SLDC LOAD  \
# 0 2017-01-01 00:00:00    13.000000  93.650000        635.0      710.0
# 1 2017-01-01 00:15:00    12.947809  93.895246        730.0      682.0
# 2 2017-01-01 00:30:00    13.016861  94.248682        686.0      660.0
# 3 2017-01-01 00:45:00    13.059741  94.521383        645.0      641.0
# 4 2017-01-01 01:00:00    13.000000  93.650000        628.0      620.0
#
#    SCADA LOAD
# 0       756.0
# 1       730.0
# 2       701.0
# 3       674.0
# 4       650.0

# %%
final_dataset.shape
# Out:
# (204480, 6)

# %%
final_dataset.size
# Out:
# 1226880

# %%
final_dataset.isnull().sum()
# Out:
# DATETIME       0
# TEMPERATURE    0
# HUMIDITY       0
# DEMAND LOAD    0
# SLDC LOAD      0
# SCADA LOAD     0
# dtype: int64

# %%
final_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204480 entries, 0 to 204479
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   DATETIME     204480 non-null  datetime64[ns]
#  1   TEMPERATURE  204480 non-null  float64
#  2   HUMIDITY     204480 non-null  float64
#  3   DEMAND LOAD  204480 non-null  float64
#  4   SLDC LOAD    204480 non-null  float64
#  5   SCADA LOAD   204480 non-null  float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 9.4 MB

# %%
final_dataset.describe()
# Out:
#                             DATETIME    TEMPERATURE       HUMIDITY  \
# count                         204480  204480.000000  204480.000000
# mean   2019-12-02 00:00:31.690141184      25.533338      63.499496
# min              2017-01-01 00:00:00       0.800000      -6.045923
# 25%              2018-06-17 11:56:15      19.260734      45.370000
# 50%              2019-12-01 23:52:30      27.089993      65.481454
# 75%              2021-05-17 11:48:45      31.558437      83.491249
# max              2022-10-31 23:45:00      47.500000     116.175782
# std                              NaN       8.240912      23.338532
#
#          DEMAND LOAD      SLDC LOAD     SCADA LOAD
# count  204480.000000  204480.000000  204480.000000
# mean     1543.867527    1534.892163    1517.803775
# min       399.000000     400.000000     449.000000
# 25%      1170.000000    1163.000000    1127.000000
# 50%      1497.000000    1485.000000    1475.000000
# 75%      1924.000000    1912.000000    1890.000000
# max      3455.000000    3345.000000    3405.000000
# std       527.497234     525.373783     531.071648

# %% [markdown]
# ### Save final dataset in excel file

# %%
final_dataset.to_excel('PreProcessedData.xlsx', index=False)

# %% [markdown]
# # Feature Engineering

# %%
dataset = pd.read_excel('PreProcessedData.xlsx')
dataset.head()
# Out:
#              DATETIME  TEMPERATURE   HUMIDITY  DEMAND LOAD  SLDC LOAD  \
# 0 2017-01-01 00:00:00    13.000000  93.650000        635.0      710.0
# 1 2017-01-01 00:15:00    12.947809  93.895246        730.0      682.0
# 2 2017-01-01 00:30:00    13.016861  94.248682        686.0      660.0
# 3 2017-01-01 00:45:00    13.059741  94.521383        645.0      641.0
# 4 2017-01-01 01:00:00    13.000000  93.650000        628.0      620.0
#
#    SCADA LOAD
# 0       756.0
# 1       730.0
# 2       701.0
# 3       674.0
# 4       650.0

# %% [markdown]
# ### Identify Holidays to use as a feature for a model

# %%
import holidays
holiday_list, list_of_years=([] for i in range(2))
year = pd.DatetimeIndex(dataset['DATETIME']).year

for i in year:
    if i not in list_of_years:
        list_of_years.append(i)

#for holiday in holidays.India(years = list_of_years).items():
#    holiday_list.append(holiday)
    
for holiday in holidays.India(years=list_of_years).items():
    holiday_list.append(holiday)
    
holidays_df = pd.DataFrame(holiday_list, columns=["DATE", "HOLIDAY"])
holidays_df
# Out:
#           DATE                        HOLIDAY
# 0   2017-01-26                   Republic Day
# 1   2017-08-15  Independence Day; Janmashtami
# 2   2017-10-02                 Gandhi Jayanti
# 3   2017-05-10                 Buddha Purnima
# 4   2017-10-19                         Diwali
# ..         ...                            ...
# 90  2022-10-09                  Milad-un-Nabi
# 91  2022-05-03                     Id-ul-Fitr
# 92  2022-07-10                         Bakrid
# 93  2022-04-15                    Good Friday
# 94  2022-12-25                      Christmas
#
# [95 rows x 2 columns]

# %%
date_range = pd.to_datetime(dataset['DATETIME']).dt.date
is_holiday = []

for date in date_range:
    if date in  list(holidays_df['DATE']):
        is_holiday.append([date,1])
    else:
        is_holiday.append([date,0])

is_holiday = pd.DataFrame(is_holiday)
is_holiday.columns = ["DATE", "IS_HOLIDAY"]
is_holiday
# Out:
#               DATE  IS_HOLIDAY
# 0       2017-01-01           0
# 1       2017-01-01           0
# 2       2017-01-01           0
# 3       2017-01-01           0
# 4       2017-01-01           0
# ...            ...         ...
# 204475  2022-10-31           0
# 204476  2022-10-31           0
# 204477  2022-10-31           0
# 204478  2022-10-31           0
# 204479  2022-10-31           0
#
# [204480 rows x 2 columns]

# %% [markdown]
# ### Creating features like Day of year, Season, Week of year, Quarter from Datetime feature

# %%
dataset = dataset.reset_index(drop=True)
is_holiday = is_holiday.reset_index(drop=True)

dataset['YEAR'] = dataset['DATETIME'].dt.year
dataset['MONTH'] = dataset['DATETIME'].dt.month
dataset['DAY'] = dataset['DATETIME'].dt.day
dataset['DAY_OF_YEAR'] = dataset['DATETIME'].dt.dayofyear
dataset['WEEK_OF_YEAR'] = dataset['DATETIME'].dt.isocalendar().week
dataset['QUARTER'] = dataset['DATETIME'].dt.quarter
dataset['SEASON'] = dataset['MONTH'] % 12 // 3 + 1
dataset['IS_HOLIDAY'] = is_holiday['IS_HOLIDAY'].values

final_set = dataset[['DATETIME', 'YEAR', 'MONTH', 'DAY', 'DAY_OF_YEAR', 'WEEK_OF_YEAR', 'QUARTER', 'SEASON', 'IS_HOLIDAY', 
                     'TEMPERATURE', 'HUMIDITY', 'DEMAND LOAD', 'SLDC LOAD', 'SCADA LOAD']]

# %%
#dataset['YEAR'] = pd.DatetimeIndex(dataset['DATETIME']).year
#dataset['MONTH'] = pd.DatetimeIndex(dataset['DATETIME']).month
#dataset['DAY'] = pd.DatetimeIndex(dataset['DATETIME']).day
#dataset['DAY_OF_YEAR'] = pd.DatetimeIndex(dataset['DATETIME']).dayofyear
#dataset['WEEK_OF_YEAR'] = pd.DatetimeIndex(dataset['DATETIME']).isocalendar().week
#dataset['QUARTER'] = pd.DatetimeIndex(dataset['DATETIME']).quarter
#dataset['SEASON'] = dataset.MONTH%12 // 3 + 1
#dataset['IS_HOLIDAY'] = is_holiday.IS_HOLIDAY

#final_set = dataset[['DATETIME', 'YEAR', 'MONTH', 'DAY', 'DAY_OF_YEAR', 'WEEK_OF_YEAR', 'QUARTER', 'SEASON', 'IS_HOLIDAY', 
#                     'TEMPERATURE', 'HUMIDITY', 'DEMAND LOAD', 'SLDC LOAD', 'SCADA LOAD']]

# %%
final_set.head()
# Out:
#              DATETIME  YEAR  MONTH  DAY  DAY_OF_YEAR  WEEK_OF_YEAR  QUARTER  \
# 0 2017-01-01 00:00:00  2017      1    1            1            52        1
# 1 2017-01-01 00:15:00  2017      1    1            1            52        1
# 2 2017-01-01 00:30:00  2017      1    1            1            52        1
# 3 2017-01-01 00:45:00  2017      1    1            1            52        1
# 4 2017-01-01 01:00:00  2017      1    1            1            52        1
#
#    SEASON  IS_HOLIDAY  TEMPERATURE   HUMIDITY  DEMAND LOAD  SLDC LOAD  \
# 0       1           0    13.000000  93.650000        635.0      710.0
# 1       1           0    12.947809  93.895246        730.0      682.0
# 2       1           0    13.016861  94.248682        686.0      660.0
# 3       1           0    13.059741  94.521383        645.0      641.0
# 4       1           0    13.000000  93.650000        628.0      620.0
#
#    SCADA LOAD
# 0       756.0
# 1       730.0
# 2       701.0
# 3       674.0
# 4       650.0

# %%
final_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204480 entries, 0 to 204479
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   DATETIME      204480 non-null  datetime64[ns]
#  1   YEAR          204480 non-null  int32
#  2   MONTH         204480 non-null  int32
#  3   DAY           204480 non-null  int32
#  4   DAY_OF_YEAR   204480 non-null  int32
#  5   WEEK_OF_YEAR  204480 non-null  UInt32
#  6   QUARTER       204480 non-null  int32
#  7   SEASON        204480 non-null  int32
#  8   IS_HOLIDAY    204480 non-null  int64
#  9   TEMPERATURE   204480 non-null  float64
#  10  HUMIDITY      204480 non-null  float64
#  11  DEMAND LOAD   204480 non-null  float64
#  12  SLDC LOAD     204480 non-null  float64
#  13  SCADA LOAD    204480 non-null  float64
# dtypes: UInt32(1), datetime64[ns](1), float64(5), int32(6), int64(1)
# memory usage: 16.6 MB

# %% [markdown]
# ### Prepare last 3 years data for evaluation metrics comparisons with last 5 years data

# %%
last_3_years_data_location = final_set.loc[final_set["DATETIME"] ==  '2019-10-31 00:00:00']
last_3_years_data_location
# Out:
#         DATETIME  YEAR  MONTH  DAY  DAY_OF_YEAR  WEEK_OF_YEAR  QUARTER  \
# 99168 2019-10-31  2019     10   31          304            44        4
#
#        SEASON  IS_HOLIDAY  TEMPERATURE  HUMIDITY  DEMAND LOAD  SLDC LOAD  \
# 99168       4           0         22.0      64.5        972.0      958.0
#
#        SCADA LOAD
# 99168       933.0

# %%
last_3_years_data_location = final_set.loc[final_set["DATETIME"] ==  '2017-10-31 00:00:00']
last_3_years_data_location
# Out:
#         DATETIME  YEAR  MONTH  DAY  DAY_OF_YEAR  WEEK_OF_YEAR  QUARTER  \
# 29088 2017-10-31  2017     10   31          304            44        4
#
#        SEASON  IS_HOLIDAY  TEMPERATURE  HUMIDITY  DEMAND LOAD  SLDC LOAD  \
# 29088       4           0         21.0     73.11        942.0      942.0
#
#        SCADA LOAD
# 29088      1004.0

# %%
last_3_years_data = final_set[29088:]
last_3_years_data.reset_index(inplace=True, drop='index')
final_set = last_3_years_data
final_set.head()
# Out:
#              DATETIME  YEAR  MONTH  DAY  DAY_OF_YEAR  WEEK_OF_YEAR  QUARTER  \
# 0 2017-10-31 00:00:00  2017     10   31          304            44        4
# 1 2017-10-31 00:15:00  2017     10   31          304            44        4
# 2 2017-10-31 00:30:00  2017     10   31          304            44        4
# 3 2017-10-31 00:45:00  2017     10   31          304            44        4
# 4 2017-10-31 01:00:00  2017     10   31          304            44        4
#
#    SEASON  IS_HOLIDAY  TEMPERATURE   HUMIDITY  DEMAND LOAD  SLDC LOAD  \
# 0       4           0    21.000000  73.110000        942.0      942.0
# 1       4           0    19.607541  71.788543        929.0      925.0
# 2       4           0    19.549853  72.342937        937.0      910.0
# 3       4           0    19.507378  74.601264        940.0      900.0
# 4       4           0    20.000000  77.770000        927.0      884.0
#
#    SCADA LOAD
# 0      1004.0
# 1       990.0
# 2       964.0
# 3       939.0
# 4       939.0

# %%
final_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175392 entries, 0 to 175391
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   DATETIME      175392 non-null  datetime64[ns]
#  1   YEAR          175392 non-null  int32
#  2   MONTH         175392 non-null  int32
#  3   DAY           175392 non-null  int32
#  4   DAY_OF_YEAR   175392 non-null  int32
#  5   WEEK_OF_YEAR  175392 non-null  UInt32
#  6   QUARTER       175392 non-null  int32
#  7   SEASON        175392 non-null  int32
#  8   IS_HOLIDAY    175392 non-null  int64
#  9   TEMPERATURE   175392 non-null  float64
#  10  HUMIDITY      175392 non-null  float64
#  11  DEMAND LOAD   175392 non-null  float64
#  12  SLDC LOAD     175392 non-null  float64
#  13  SCADA LOAD    175392 non-null  float64
# dtypes: UInt32(1), datetime64[ns](1), float64(5), int32(6), int64(1)
# memory usage: 14.2 MB

# %%
final_set.to_excel('last_3_years.xlsx', index=False)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Seasonal Decompose for Load Data

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 11, 9

decomposed_demand_load = sm.tsa.seasonal_decompose(final_set['SCADA LOAD'],period=35700) 

# THE FREQUENCY IS ANNUAL.
# 1 Days = 96 Slots
# 1 Month = 96 * 31 Days = 2976 slots approx.
# 1 Year = 2976 * 12 Months = 35712 slots approx. 

figure = decomposed_demand_load.plot()
plt.show()

# %% [markdown]
# ## Load data distribution Between Demand and SCADA

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.distplot(final_set['DEMAND LOAD'].dropna(), ax=ax, kde=False).set_title('DEMAND LOAD', fontsize=16)
sns.distplot(final_set['SCADA LOAD'].dropna(), ax=ax, kde=False).set_title('SCADA LOAD', fontsize=16)
plt.xlabel('MW Power', fontsize=15)
plt.legend(['DEMAND', 'SCADA'])
ax.set_yticks(np.linspace(0, 6000, 15))
plt.title('Distribution of energy demanded and Actual load')
plt.show()

# %% [markdown]
# ## Load Data Distribution of Month of years (2019-2022)

# %%
fig, axs = plt.subplots(1, 1,  figsize=(12,7))

final_set.set_index('DATETIME', inplace=True)

groups = final_set['SCADA LOAD'].groupby(pd.Grouper(freq='M'))

df = pd.DataFrame()

for name, group in groups:
    df[name.month] = pd.Series(group.values)

df.boxplot(ax=axs)
axs.set_xlabel('Month')
axs.set_ylabel('SCADA LOAD (MW)')
axs.set_title('SCADA LOAD data plot month of year 2019-2022')
axs.set_yticks(np.linspace(0,3500,20))
plt.subplots_adjust(hspace=0.5)

plt.show()

# %% [markdown]
# ## Monthly Mean SCADA Load Data (2019-2022)

# %%
df_month = final_set.resample('M').mean()

fig, ax = plt.subplots(figsize=(14, 7))
colors = ['red', 'blue', 'green', 'purple', 'orange', 'gray']

for i, year in enumerate(range(2019, 2023)):
    yearly_data = df_month[df_month.index.year == year]

    ax.bar(yearly_data.index,
           yearly_data['SCADA LOAD'],
           width=25,
           color=colors[i],
           label=str(year))

ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))

plt.xticks(rotation=90)
ax.set_ylabel('SCADA LOAD')
ax.set_title('Monthly Mean SCADA Load Data (2019-2022)')
ax.legend()

plt.show()

# %% [markdown]
# ## Minimum and Maximum SCADA Load profile (2019-2022)

# %%
df_hourly = final_set.resample("H").mean()
df_hourly.reset_index(inplace=True)

df_hourly['DATETIME'] = df_hourly['DATETIME'].dt.year
min_max_load = df_hourly.groupby('DATETIME')['SCADA LOAD'].agg(['min', 'max'])

ax = min_max_load.plot.bar(rot=0,  width=0.7, edgecolor='black')

for i, val in enumerate(min_max_load['min']):
    ax.text(i-0.35, val+40, str(val), color='black', fontweight='bold')
for i, val in enumerate(min_max_load['max']):
    ax.text(i+0.00, val+40, str(val), color='black', fontweight='bold')

    
ax.set_xlabel('Year')
ax.set_title('Minimum and Maximum SCADA Load profile (2019-2022)')
ax.set_ylabel('SCADA Load')
plt.show()

# %% [markdown]
# ## Weekly Mean Load Data of DEMAND, SCADA and SLDC (2019-2022)

# %%
SCADA_weekly = final_set['SCADA LOAD'].resample('W').mean()
SLDC_weekly = final_set['SLDC LOAD'].resample('W').mean()
Demand_weekly = final_set['DEMAND LOAD'].resample('W').mean()

plt.figure(figsize=(12, 6))
sns.lineplot(data=SCADA_weekly, label='SCADA')
sns.lineplot(data=SLDC_weekly, label='SLDC')
sns.lineplot(data=Demand_weekly, label='DEMAND')
plt.xlabel('Year')
plt.ylabel('Load (MW)')
plt.title('Weekly Mean Load Data of DEMAND, SCADA and SLDC (2019-2022)')
plt.legend()
plt.show()

# %% [markdown]
# ## Seasonal Decompose for Weather Data

# %%
rcParams['figure.figsize'] = 11, 9

decomposed_demand_load = sm.tsa.seasonal_decompose(final_set['TEMPERATURE'],period=35700) 

# THE FREQUENCY IS ANNUAL.
# 1 Days = 96 Slots
# 1 Month = 96 * 31 Days = 2976 slots approx.
# 1 Year = 2976 * 12 Months = 35712 slots approx. 

figure = decomposed_demand_load.plot()
plt.show()

# %% [markdown]
# ## Weather Data Distribution of Month of years (2019-2022)

# %%
fig, axs = plt.subplots(1, 1,  figsize=(12,7))

groups = final_set['TEMPERATURE'].groupby(pd.Grouper(freq='M'))

df = pd.DataFrame()

for name, group in groups:
    df[name.month] = pd.Series(group.values)

df.boxplot(ax=axs)
axs.set_xlabel('Month')
axs.set_ylabel('TEMPERATURE (C)')
axs.set_title('Temperature data plot month of year 2019-2022')
axs.set_yticks(np.linspace(0,50,20))
plt.subplots_adjust(hspace=0.5)

plt.show()

# %% [markdown]
# ## Weekly Mean Temperature and Humidity Data (2019-2022)

# %%
Temp_weekly = final_set['TEMPERATURE'].resample('W').mean()
Humd_weekly = final_set['HUMIDITY'].resample('W').mean()

plt.figure(figsize=(15, 6))
sns.lineplot(data=Temp_weekly, label='TEMP')
sns.lineplot(data=Humd_weekly, label='HUMIDITY')
plt.xlabel('Month')
plt.ylabel('Temperature and Humidity')
plt.title('Weekly Mean Temperature and Humidity Data (2019-2022)')
plt.legend()
plt.show()

# %% [markdown]
# ## Minimum and Maximum Temperature profile (2019-2022)

# %%
df_hourly = final_set.resample("H").mean()
df_hourly.reset_index(inplace=True)

df_hourly['DATETIME'] = df_hourly['DATETIME'].dt.year
min_max_load = df_hourly.groupby('DATETIME')['TEMPERATURE'].agg(['min', 'max'])

ax = min_max_load.plot.bar(rot=0,  width=0.7, edgecolor='black')

for i, val in enumerate(min_max_load['min']):
    ax.text(i-0.35, val+0.5, str(round(val ,2)), color='black', fontweight='bold')
for i, val in enumerate(min_max_load['max']):
    ax.text(i+0.02, val+0.5, str(round(val ,2)), color='black', fontweight='bold')
    
ax.set_xlabel('Year')
ax.set_title('Minimum and Maximum Temperature profile (2019-2022)')
ax.set_ylabel('Temperature (C)')
plt.show()

# %% [markdown]
# ## Monthly SCADA Load and Weather Data (2019-2022)

# %%
load_monthly = final_set.resample('M').mean()
Temp_monthly = final_set.resample('M').mean()

fig, ax1 = plt.subplots(figsize=(13, 7))

ax1.plot(load_monthly["SCADA LOAD"], color="blue")
ax1.set_xlabel("Year")
ax1.set_ylabel("SCADA LOAD", color="blue")
ax1.tick_params(axis="y", labelcolor="blue")

ax2 =ax1.twinx()

ax2.plot(Temp_monthly["TEMPERATURE"], color="red")
ax2.set_ylabel("Temperature (C)", color="red")
ax2.tick_params(axis="y", labelcolor="red")

ax1.legend(["Load Consumption"], loc="upper left")
ax2.legend(["Temperature"], loc="upper right")

plt.title("Monthly SCADA Load and Weather Data (2019-2022)")
plt.show()

# %% [markdown]
# # Spliting of dataset into Train, Validation and Test Set

# %%
final_set.reset_index(inplace=True)
min_date = final_set.DATETIME.dt.date.min()
max_date = final_set.DATETIME.dt.date.max()

print('Start Date:', min_date)
print('End Date:', max_date)
# Out:
# Start Date: 2017-10-31
# End Date: 2022-10-31

# %%
final_set.set_index('DATETIME', inplace=True)

# %% [markdown]
# Split data into 70% of Training set, 10% of Validation Set and 20% of Test set

# %% [markdown]
# ## Train set

# %%
train_percent = 0.7

time_between = max_date - min_date

train_start_date = min_date + pd.DateOffset(hours=0, minutes=0)
print('Start Date : ', train_start_date)

train_cutoff_date = min_date + train_percent * time_between
train_end_date = train_cutoff_date + pd.DateOffset(hours=23, minutes=45)
print('End Date   : ', train_end_date)

tsp_train_set = final_set.loc[train_start_date:train_end_date]
tsp_train_set.reset_index(inplace=True)
tsp_train_set.head()
# Out:
# Start Date :  2017-10-31 00:00:00
# End Date   :  2021-05-01 23:45:00
#              DATETIME  index  YEAR  MONTH  DAY  DAY_OF_YEAR  WEEK_OF_YEAR  \
# 0 2017-10-31 00:00:00      0  2017     10   31          304            44
# 1 2017-10-31 00:15:00      1  2017     10   31          304            44
# 2 2017-10-31 00:30:00      2  2017     10   31          304            44
# 3 2017-10-31 00:45:00      3  2017     10   31          304            44
# 4 2017-10-31 01:00:00      4  2017     10   31          304            44
#
#    QUARTER  SEASON  IS_HOLIDAY  TEMPERATURE   HUMIDITY  DEMAND LOAD  \
# 0        4       4           0    21.000000  73.110000        942.0
# 1        4       4           0    19.607541  71.788543        929.0
# 2        4       4           0    19.549853  72.342937        937.0
# 3        4       4           0    19.507378  74.601264        940.0
# 4        4       4           0    20.000000  77.770000        927.0
#
#    SLDC LOAD  SCADA LOAD
# 0      942.0      1004.0
# 1      925.0       990.0
# 2      910.0       964.0
# 3      900.0       939.0
# 4      884.0       939.0

# %% [markdown]
# ## Validation Set

# %%
val_percent = 0.1

val_start_date = train_cutoff_date + pd.DateOffset(days=1)
print('Start Date : ', val_start_date)

val_cutoff_date = val_start_date.date() + val_percent * time_between
val_end_date = val_cutoff_date + pd.DateOffset(hours=23, minutes=45)
print('End Date   : ', val_end_date)

tsp_val_set = final_set.loc[val_start_date:val_end_date]
tsp_val_set.reset_index(inplace=True)
tsp_val_set.head()
# Out:
# Start Date :  2021-05-02 00:00:00
# End Date   :  2021-10-31 23:45:00
#              DATETIME   index  YEAR  MONTH  DAY  DAY_OF_YEAR  WEEK_OF_YEAR  \
# 0 2021-05-02 00:00:00  122784  2021      5    2          122            17
# 1 2021-05-02 00:15:00  122785  2021      5    2          122            17
# 2 2021-05-02 00:30:00  122786  2021      5    2          122            17
# 3 2021-05-02 00:45:00  122787  2021      5    2          122            17
# 4 2021-05-02 01:00:00  122788  2021      5    2          122            17
#
#    QUARTER  SEASON  IS_HOLIDAY  TEMPERATURE   HUMIDITY  DEMAND LOAD  \
# 0        2       2           0    30.000000  27.060000       1785.0
# 1        2       2           0    28.601498  25.845575       1770.0
# 2        2       2           0    28.422473  26.198311       1760.0
# 3        2       2           0    28.265077  27.989293       1740.0
# 4        2       2           0    29.000000  30.660000       1713.0
#
#    SLDC LOAD  SCADA LOAD
# 0     1831.0      1833.0
# 1     1812.0      1814.0
# 2     1793.0      1795.0
# 3     1770.0      1772.0
# 4     1743.0      1747.0

# %% [markdown]
# ## Test Set

# %%
test_percent = 0.2

test_start_date = val_cutoff_date + pd.DateOffset(days=1)
print('Start Date : ', test_start_date)

test_end_date = max_date + pd.DateOffset(hours=23, minutes=45)
print('End Date   : ', test_end_date)

tsp_test_set = final_set.loc[test_start_date:test_end_date]
tsp_test_set.reset_index(inplace=True)
tsp_test_set.head()
# Out:
# Start Date :  2021-11-01 00:00:00
# End Date   :  2022-10-31 23:45:00
#              DATETIME   index  YEAR  MONTH  DAY  DAY_OF_YEAR  WEEK_OF_YEAR  \
# 0 2021-11-01 00:00:00  140352  2021     11    1          305            44
# 1 2021-11-01 00:15:00  140353  2021     11    1          305            44
# 2 2021-11-01 00:30:00  140354  2021     11    1          305            44
# 3 2021-11-01 00:45:00  140355  2021     11    1          305            44
# 4 2021-11-01 01:00:00  140356  2021     11    1          305            44
#
#    QUARTER  SEASON  IS_HOLIDAY  TEMPERATURE   HUMIDITY  DEMAND LOAD  \
# 0        4       4           0    20.000000  68.380000        817.0
# 1        4       4           0    19.077446  64.940913        812.0
# 2        4       4           0    18.977350  63.692767        789.0
# 3        4       4           0    18.874595  64.866351        768.0
# 4        4       4           0    19.000000  68.180000        668.0
#
#    SLDC LOAD  SCADA LOAD
# 0      774.0       757.0
# 1      756.0       733.0
# 2      742.0       718.0
# 3      722.0       702.0
# 4      707.0       684.0

# %% [markdown]
# # Data Normalization

# %%
scaler = MinMaxScaler(feature_range = (0, 1))

# %%
tsp_scaled_train_set = tsp_train_set.drop(labels=['DATETIME'],axis=1).copy()
tsp_scaled_val_set = tsp_val_set.drop(labels=['DATETIME'],axis=1).copy()
tsp_scaled_test_set = tsp_test_set.drop(labels=['DATETIME'],axis=1).copy()

# %%
tsp_scaled_train_set = scaler.fit_transform(tsp_scaled_train_set)
tsp_scaled_val_set = scaler.fit_transform(tsp_scaled_val_set)
tsp_scaled_test_set = scaler.fit_transform(tsp_scaled_test_set)

# %% [markdown]
# ## Reshape data for input of CNN-LSTM Model

# %%
def create_sequences(ds, lb, look_back):
    windowed_dataset = []
    labels = []
    for i in range(look_back, ds.shape[0] + 1):
        windowed_dataset.append(ds[i - look_back:i])
        labels.append(lb[i - 1])
        
    return np.array(windowed_dataset), np.array(labels)

# %% [markdown]
# ### The input data can then be reshaped to have the required structure: [samples, features, timesteps]

# %%
look_back = 96
X_train, y_train = create_sequences(tsp_scaled_train_set[:,0:-1], tsp_scaled_train_set[:, -1], look_back)
X_val, y_val = create_sequences(tsp_scaled_val_set[:,0:-1], tsp_scaled_val_set[:, -1], look_back)
X_test, y_test = create_sequences(tsp_scaled_test_set[:,0:-1], tsp_scaled_test_set[:, -1], look_back)

print(X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape)
# Out:
# (122689, 96, 13) (122689,) (17473, 96, 13) (17473,) (34945, 96, 13) (34945,)

# %% [markdown]
# # CNN-LSTM Model Implementation

# %%
tf.keras.backend.clear_session()

# CNN Implementations
model1 = tf.keras.models.Sequential([
    tf.keras.layers.Conv1D(filters=32,
                           kernel_size=2, 
                           strides=1, 
                           activation="relu", 
                           input_shape=(X_train.shape[1], X_train.shape[2])),
    tf.keras.layers.MaxPooling1D(pool_size=2, strides=1),
    tf.keras.layers.Conv1D(filters=16, kernel_size=3, strides=1, activation="relu"),
    tf.keras.layers.MaxPooling1D(pool_size=2, strides=1),
    
# LSTM Implementations
    tf.keras.layers.LSTM(32),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(5, activation="relu"),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(1, kernel_regularizer=L1(0.03))])

model1.compile(loss=tf.keras.losses.MeanSquaredError(),
              optimizer='adam',
              metrics=['mae'])

model1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 95, 32)         │           864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 94, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 92, 16)         │         1,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 91, 16)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 32)             │         6,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 5)              │           165 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 5)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,859 (34.61 KB)
#  Trainable params: 8,859 (34.61 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
plot_model(model1, to_file='model1.png', show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %% [markdown]
# ## Train Model

# %%
tf.config.run_functions_eagerly(True)
history = model1.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=40, batch_size=100)
# Out:
# Epoch 1/40
#  847/1227 ━━━━━━━━━━━━━━━━━━━━ 5:12 823ms/step - loss: 0.0046 - mae: 0.0415
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[207], line 2
#       1 tf.config.run_functions_eagerly(True)
# ----> 2 history = model1.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=40, batch_size=100)
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:399, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397 for begin_step, end_step, iterator in epoch_iterator:
#     398     callbacks.on_train_batch_begin(begin_step)
# --> 399     logs = self.train_function(iterator)
#     400     callbacks.on_train_batch_end(end_step, logs)
#     401     if self.stop_training:
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:241, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     237 def function(iterator):
#     238     if isinstance(
#     239         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240     ):
# --> 241         opt_outputs = multi_step_on_iterator(iterator)
#     242         if not opt_outputs.has_value():
#     243             raise StopIteration
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\util\traceback_utils.py:164, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     162 filtered_tb = None
#     163 try:
# --> 164   return fn(*args, **kwargs)
#     165 except Exception as e:
#     166   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:810, in Function.__call__(self, *args, **kwds)
#     808 if self._run_functions_eagerly:
#     809   with trace.Trace(self._name, tf_function_call="eager"):
# --> 810     return self._python_function(*args, **kwds)
#     812 # Only count the statistics the first time, before initialization took
#     813 # place.
#     814 if self._created_variables is None:
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\autograph\impl\api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:154, in TensorFlowTrainer._make_function.<locals>.multi_step_on_iterator(iterator)
#     150 @tf.autograph.experimental.do_not_convert
#     151 def multi_step_on_iterator(iterator):
#     152     if self.steps_per_execution == 1:
#     153         return tf.experimental.Optional.from_value(
# --> 154             one_step_on_data(iterator.get_next())
#     155         )
#     157     # the spec is set lazily during the tracing of `tf.while_loop`
#     158     empty_outputs = tf.experimental.Optional.empty(None)
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:125, in TensorFlowTrainer._autoconvert_optionals.<locals>.wrapper(data)
#     117 @functools.wraps(step_func)
#     118 def wrapper(data):
#     119     converted_data = tree.map_structure(
#     120         lambda i: (
#     121             None if isinstance(i, tf.experimental.Optional) else i
#     122         ),
#     123         data,
#     124     )
# --> 125     result = step_func(converted_data)
#     126     return result
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\util\traceback_utils.py:164, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     162 filtered_tb = None
#     163 try:
# --> 164   return fn(*args, **kwargs)
#     165 except Exception as e:
#     166   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:810, in Function.__call__(self, *args, **kwds)
#     808 if self._run_functions_eagerly:
#     809   with trace.Trace(self._name, tf_function_call="eager"):
# --> 810     return self._python_function(*args, **kwds)
#     812 # Only count the statistics the first time, before initialization took
#     813 # place.
#     814 if self._created_variables is None:
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\autograph\impl\api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:134, in TensorFlowTrainer._make_function.<locals>.one_step_on_data(data)
#     131 @tf.autograph.experimental.do_not_convert
#     132 def one_step_on_data(data):
#     133     """Runs a single training step on a batch of data."""
# --> 134     outputs = self.distribute_strategy.run(step_function, args=(data,))
#     135     outputs = reduce_per_replica(
#     136         outputs,
#     137         self.distribute_strategy,
#     138         reduction="auto",
#     139     )
#     140     return outputs
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1673, in StrategyBase.run(***failed resolving arguments***)
#    1668 with self.scope():
#    1669   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1670   # applied when the caller is also in Eager mode.
#    1671   fn = autograph.tf_convert(
#    1672       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1673   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3263, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    3261   kwargs = {}
#    3262 with self._container_strategy().scope():
# -> 3263   return self._call_for_each_replica(fn, args, kwargs)
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:4061, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    4059 def _call_for_each_replica(self, fn, args, kwargs):
#    4060   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 4061     return fn(*args, **kwargs)
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\autograph\impl\api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:59, in TensorFlowTrainer.train_step(self, data)
#      57 with tf.GradientTape() as tape:
#      58     if self._call_has_training_arg:
# ---> 59         y_pred = self(x, training=True)
#      60     else:
#      61         y_pred = self(x)
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\layers\layer.py:1002, in Layer.__call__(self, *args, **kwargs)
#    1000         outputs = super().__call__(*args, **kwargs)
#    1001 else:
# -> 1002     outputs = super().__call__(*args, **kwargs)
#    1003 # Change the layout for the layer output if needed.
#    1004 # This is useful for relayout intermediate tensor in the model
#    1005 # to achieve the optimal performance.
#    1006 distribution = distribution_lib.distribution()
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\ops\operation.py:63, in Operation.__call__(self, *args, **kwargs)
#      58                 call_fn = self.call
#      59     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      60         call_fn,
#      61         object_name=(f"{self.__class__.__name__}.call()"),
#      62     )
# ---> 63     return call_fn(*args, **kwargs)
#      65 # Plain flow.
#      66 if any_symbolic_tensors(args, kwargs):
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\utils\traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\models\sequential.py:239, in Sequential.call(self, inputs, training, mask, **kwargs)
#     237 def call(self, inputs, training=None, mask=None, **kwargs):
#     238     if self._functional:
# --> 239         return self._functional.call(
#     240             inputs, training=training, mask=mask, **kwargs
#     241         )
#     243     # Fallback: Just apply the layer sequence.
#     244     # This typically happens if `inputs` is a nested struct.
#     245     for layer in self.layers:
#     246         # During each iteration, `inputs` are the inputs to `layer`, and
#     247         # `outputs` are the outputs of `layer` applied to `inputs`. At the
#     248         # end of each iteration `inputs` is set to `outputs` to prepare for
#     249         # the next layer.
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\models\functional.py:184, in Functional.call(self, inputs, training, mask, **kwargs)
#     182         if mask is not None:
#     183             backend.set_keras_mask(x, mask)
# --> 184 outputs = self._run_through_graph(
#     185     inputs,
#     186     operation_fn=lambda op: operation_fn(
#     187         op, training=training, **kwargs
#     188     ),
#     189 )
#     190 return unpack_singleton(outputs)
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\ops\function.py:210, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     208     operation = self._get_operation_for_node(node)
#     209     op = operation_fn(operation)
# --> 210     outputs = op(*args, **kwargs)
#     212 # Update tensor_dict.
#     213 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\models\functional.py:707, in operation_fn.<locals>.call(*args, **kwargs)
#     701     if (
#     702         name in getattr(operation, "_call_context_args", {})
#     703         and value is not None
#     704     ):
#     705         kwargs[name] = value
# --> 707 return operation(*args, **kwargs)
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\layers\layer.py:1002, in Layer.__call__(self, *args, **kwargs)
#    1000         outputs = super().__call__(*args, **kwargs)
#    1001 else:
# -> 1002     outputs = super().__call__(*args, **kwargs)
#    1003 # Change the layout for the layer output if needed.
#    1004 # This is useful for relayout intermediate tensor in the model
#    1005 # to achieve the optimal performance.
#    1006 distribution = distribution_lib.distribution()
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\ops\operation.py:63, in Operation.__call__(self, *args, **kwargs)
#      58                 call_fn = self.call
#      59     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      60         call_fn,
#      61         object_name=(f"{self.__class__.__name__}.call()"),
#      62     )
# ---> 63     return call_fn(*args, **kwargs)
#      65 # Plain flow.
#      66 if any_symbolic_tensors(args, kwargs):
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\utils\traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\layers\rnn\lstm.py:583, in LSTM.call(self, sequences, initial_state, mask, training)
#     582 def call(self, sequences, initial_state=None, mask=None, training=False):
# --> 583     return super().call(
#     584         sequences, mask=mask, training=training, initial_state=initial_state
#     585     )
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\layers\rnn\rnn.py:425, in RNN.call(self, sequences, initial_state, mask, training)
#     419 # Prepopulate the dropout state so that the inner_loop is stateless
#     420 # this is particularly important for JAX backend.
#     421 self._maybe_config_dropout_masks(
#     422     self.cell, sequences[:, 0, :], initial_state
#     423 )
# --> 425 last_output, outputs, states = self.inner_loop(
#     426     sequences=sequences,
#     427     initial_state=initial_state,
#     428     mask=mask,
#     429     training=training,
#     430 )
#     431 last_output = ops.cast(last_output, self.compute_dtype)
#     432 outputs = ops.cast(outputs, self.compute_dtype)
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\layers\rnn\lstm.py:578, in LSTM.inner_loop(self, sequences, initial_state, mask, training)
#     571 if self.use_cudnn is True:
#     572     raise ValueError(
#     573         "use_cudnn=True was specified, "
#     574         "but cuDNN is not supported for this layer configuration "
#     575         "with this backend. Pass use_cudnn='auto' to fallback "
#     576         "to a non-cuDNN implementation."
#     577     )
# --> 578 return super().inner_loop(
#     579     sequences, initial_state, mask=mask, training=training
#     580 )
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\layers\rnn\rnn.py:350, in RNN.inner_loop(self, sequences, initial_state, mask, training)
#     347 if not tree.is_nested(initial_state):
#     348     initial_state = [initial_state]
# --> 350 return backend.rnn(
#     351     step,
#     352     sequences,
#     353     initial_state,
#     354     go_backwards=self.go_backwards,
#     355     mask=mask,
#     356     unroll=self.unroll,
#     357     input_length=sequences.shape[1],
#     358     zero_output_for_mask=self.zero_output_for_mask,
#     359     return_all_outputs=self.return_sequences,
#     360 )
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\backend\tensorflow\rnn.py:262, in rnn(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length, time_major, zero_output_for_mask, return_all_outputs)
#     257 input_time_zero = tree.pack_sequence_as(
#     258     inputs, [inp[0] for inp in flattened_inputs]
#     259 )
#     260 # output_time_zero is used to determine the cell output shape and its
#     261 # dtype.  the value is discarded.
# --> 262 output_time_zero, _ = step_function(
#     263     input_time_zero, tuple(initial_states) + tuple(constants)
#     264 )
#     266 output_ta_size = time_steps_t if return_all_outputs else 1
#     267 output_ta = tuple(
#     268     tf.TensorArray(
#     269         dtype=out.dtype,
#    (...)    274     for i, out in enumerate(tree.flatten(output_time_zero))
#     275 )
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\layers\rnn\rnn.py:342, in RNN.inner_loop.<locals>.step(inputs, states)
#     340 if backend.backend() == "torch" and self.stateful:
#     341     states = tree.map_structure(ops.copy, states)
# --> 342 output, new_states = self.cell(inputs, states, **cell_kwargs)
#     343 if not tree.is_nested(new_states):
#     344     new_states = [new_states]
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\layers\layer.py:1002, in Layer.__call__(self, *args, **kwargs)
#    1000         outputs = super().__call__(*args, **kwargs)
#    1001 else:
# -> 1002     outputs = super().__call__(*args, **kwargs)
#    1003 # Change the layout for the layer output if needed.
#    1004 # This is useful for relayout intermediate tensor in the model
#    1005 # to achieve the optimal performance.
#    1006 distribution = distribution_lib.distribution()
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\ops\operation.py:63, in Operation.__call__(self, *args, **kwargs)
#      58                 call_fn = self.call
#      59     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      60         call_fn,
#      61         object_name=(f"{self.__class__.__name__}.call()"),
#      62     )
# ---> 63     return call_fn(*args, **kwargs)
#      65 # Plain flow.
#      66 if any_symbolic_tensors(args, kwargs):
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\utils\traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\layers\rnn\lstm.py:277, in LSTMCell.call(self, inputs, states, training)
#     274     dp_mask = self.get_dropout_mask(inputs)
#     275     inputs = inputs * dp_mask
# --> 277 z = ops.matmul(inputs, self.kernel)
#     279 z = ops.add(z, ops.matmul(h_tm1, self.recurrent_kernel))
#     280 if self.use_bias:
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\ops\numpy.py:5114, in matmul(x1, x2)
#    5112 if any_symbolic_tensors((x1, x2)):
#    5113     return Matmul().symbolic_call(x1, x2)
# -> 5114 return backend.numpy.matmul(x1, x2)
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\backend\tensorflow\numpy.py:520, in matmul(x1, x2)
#     518     output_type = None
#     519 x1 = tf.cast(x1, compute_dtype)
# --> 520 x2 = tf.cast(x2, compute_dtype)
#     522 def with_combined_batch_dimensions(a, b, output_shape, fn_3d):
#     523     a_sparse = isinstance(a, tf.SparseTensor)
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\util\traceback_utils.py:164, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     162 filtered_tb = None
#     163 try:
# --> 164   return fn(*args, **kwargs)
#     165 except Exception as e:
#     166   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\util\dispatch.py:1264, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1262 # Fallback dispatch system (dispatch v1):
#    1263 try:
# -> 1264   return dispatch_target(*args, **kwargs)
#    1265 except (TypeError, ValueError):
#    1266   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1267   # TypeError, when given unexpected types.  So we need to catch both.
#    1268   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\ops\math_ops.py:1044, in cast(x, dtype, name)
#    1038   x = indexed_slices.IndexedSlices(values_cast, x.indices, x.dense_shape)
#    1039 else:
#    1040   # TODO(josh11b): If x is not already a Tensor, we could return
#    1041   # ops.convert_to_tensor(x, dtype=dtype, ...)  here, but that
#    1042   # allows some conversions that cast() can't do, e.g. casting numbers to
#    1043   # strings.
# -> 1044   x = ops.convert_to_tensor(x, name="x")
#    1045   if x.dtype.is_complex and base_type.is_floating:
#    1046     logging.warn(
#    1047         f"You are casting an input of type {x.dtype.name} to an "
#    1048         f"incompatible dtype {base_type.name}.  This will "
#    1049         "discard the imaginary part and may not be what you "
#    1050         "intended."
#    1051     )
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\profiler\trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\framework\ops.py:757, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     755 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     756 preferred_dtype = preferred_dtype or dtype_hint
# --> 757 return tensor_conversion_registry.convert(
#     758     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     759 )
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py:209, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     207 overload = getattr(value, "__tf_tensor__", None)
#     208 if overload is not None:
# --> 209   return overload(dtype, name)  #  pylint: disable=not-callable
#     211 for base_type, conversion_func in get(type(value)):
#     212   # If dtype is None but preferred_dtype is not None, we try to
#     213   # cast to preferred_dtype first.
#     214   ret = None
#
# File c:\Python\Python3.13\Lib\site-packages\keras\src\backend\tensorflow\core.py:85, in Variable.__tf_tensor__(self, dtype, name)
#      84 def __tf_tensor__(self, dtype=None, name=None):
# ---> 85     return tf.convert_to_tensor(self.value, dtype=dtype, name=name)
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\util\traceback_utils.py:164, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     162 filtered_tb = None
#     163 try:
# --> 164   return fn(*args, **kwargs)
#     165 except Exception as e:
#     166   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\util\dispatch.py:1264, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1262 # Fallback dispatch system (dispatch v1):
#    1263 try:
# -> 1264   return dispatch_target(*args, **kwargs)
#    1265 except (TypeError, ValueError):
#    1266   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1267   # TypeError, when given unexpected types.  So we need to catch both.
#    1268   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\framework\tensor_conversion.py:161, in convert_to_tensor_v2_with_dispatch(value, dtype, dtype_hint, name)
#      96 @tf_export.tf_export("convert_to_tensor", v1=[])
#      97 @dispatch.add_dispatch_support
#      98 def convert_to_tensor_v2_with_dispatch(
#      99     value, dtype=None, dtype_hint=None, name=None
#     100 ) -> tensor_lib.Tensor:
#     101   """Converts the given `value` to a `Tensor`.
#     102
#     103   This function converts Python objects of various types to `Tensor`
#    (...)    159     ValueError: If the `value` is a tensor not of given `dtype` in graph mode.
#     160   """
# --> 161   return convert_to_tensor_v2(
#     162       value, dtype=dtype, dtype_hint=dtype_hint, name=name
#     163   )
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\framework\tensor_conversion.py:171, in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#     169 """Converts the given `value` to a `Tensor`."""
#     170 # preferred_dtype = preferred_dtype or dtype_hint
# --> 171 return tensor_conversion_registry.convert(
#     172     value, dtype, name, preferred_dtype=dtype_hint
#     173 )
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)    230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:2378, in _dense_var_to_tensor(var, dtype, name, as_ref)
#    2377 def _dense_var_to_tensor(var, dtype=None, name=None, as_ref=False):
# -> 2378   return var._dense_var_to_tensor(dtype=dtype, name=name, as_ref=as_ref)
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1624, in BaseResourceVariable._dense_var_to_tensor(***failed resolving arguments***)
#    1622   return self.read_value().op.inputs[0]
#    1623 else:
# -> 1624   return self.value()
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:658, in BaseResourceVariable.value(self)
#     656   return self._cached_value
#     657 with ops.colocate_with(None, ignore_existing=True):
# --> 658   return self._read_variable_op()
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:843, in BaseResourceVariable._read_variable_op(self, no_copy)
#     841       result = read_and_set_handle(no_copy)
#     842 else:
# --> 843   result = read_and_set_handle(no_copy)
#     845 if not context.executing_eagerly():
#     846   # Note that if a control flow context is active the input of the read op
#     847   # might not actually be the handle. This line bypasses it.
#     848   record.record_operation(
#     849       "ReadVariableOp", [result], [self.handle],
#     850       backward_function=lambda x: [x],
#     851       forward_function=lambda x: [x])
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:833, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     831 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     832   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 833 result = gen_resource_variable_ops.read_variable_op(
#     834     self.handle, self._dtype)
#     835 _maybe_set_handle_data(self._dtype, self.handle, result)
#     836 return result
#
# File c:\Python\Python3.13\Lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py:534, in read_variable_op(resource, dtype, name)
#     532 if tld.is_eager:
#     533   try:
# --> 534     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     535       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     536     return _result
#     537   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Save the model

# %%
pre_3y_saved_model = pickle.dumps(model1)
model_for_3year_data_pickle = pickle.loads(pre_3y_saved_model)

# %% [markdown]
# # Evaluate and Predict

# %%
loss, mae = model1.evaluate(X_test, y_test)
# Out:
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0041 - mae: 0.0545

# %%
y_pred = model1.predict(X_test)
# Out:
# 1093/1093 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step

# %% [markdown]
# ### Training Loss v/s Validation Loss

# %%
plt.figure(figsize=(15, 6))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Training loss vs Validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %% [markdown]
# ### Training MAE v/s Validation MAE

# %%
plt.figure(figsize=(15, 6))

plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('Model train vs Validation mae')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %% [markdown]
# ### Inverse Transform on test dataset to get the actual value

# %%
y_test_array = np.repeat(y_test, 14, axis=-1)
y_test_array_new = y_test_array.reshape(-1, 14)
y_test_actual = scaler.inverse_transform(y_test_array_new)[:, -1]
y_test_actual
# Out:
# array([804., 780., 759., ..., 982., 957., 933.], shape=(34945,))

# %%
y_test_pred_array = np.repeat(y_pred, 14, axis=-1)
y_test_predict = scaler.inverse_transform(y_test_pred_array)[:, -1]
y_test_predict
# Out:
# array([885.6239 , 869.56085, 852.755  , ..., 930.2935 , 907.6895 ,
#        886.854  ], shape=(34945,), dtype=float32)

# %% [markdown]
# ### Creating a dataframe to compare the actual SCADA LOAD with predicted SCADA LOAD and also check for OD/UD of predicted value

# %%
actual_load_df = pd.DataFrame(y_test_actual, columns=['ACTUAL SCADA LOAD'])
pred_load_df = pd.DataFrame(y_test_predict, columns=['PRED. SCADA LOAD'])

# %%
new_date = test_start_date + pd.DateOffset(hours=23, minutes=45)
date_index = pd.date_range(start=new_date, end=test_end_date, freq='15T')
datetime_df = pd.DataFrame({'DATETIME': date_index + pd.DateOffset(hours=0, minutes=0)})

# %%
comp_df = pd.concat([datetime_df, actual_load_df, pred_load_df], axis=1)

comp_df['difference'] = comp_df['PRED. SCADA LOAD'].astype(int) - comp_df['ACTUAL SCADA LOAD'].astype(int)

comp_df['OD/UD PRED. SCADA LOAD'] = comp_df['difference'].apply(lambda x: '{0}{1}'.format('-' if x < 0 else '+', abs(x)))

comp_df = pd.concat([datetime_df, actual_load_df.astype(int), pred_load_df.astype(int), comp_df['OD/UD PRED. SCADA LOAD']], axis=1)
comp_df
# Out:
#                  DATETIME  ACTUAL SCADA LOAD  PRED. SCADA LOAD  \
# 0     2021-11-01 23:45:00                804               885
# 1     2021-11-02 00:00:00                780               869
# 2     2021-11-02 00:15:00                759               852
# 3     2021-11-02 00:30:00                741               840
# 4     2021-11-02 00:45:00                723               832
# ...                   ...                ...               ...
# 34940 2022-10-31 22:45:00               1032               972
# 34941 2022-10-31 23:00:00               1007               950
# 34942 2022-10-31 23:15:00                982               930
# 34943 2022-10-31 23:30:00                957               907
# 34944 2022-10-31 23:45:00                933               886
#
#       OD/UD PRED. SCADA LOAD
# 0                        +81
# 1                        +89
# 2                        +93
# 3                        +99
# 4                       +109
# ...                      ...
# 34940                    -60
# 34941                    -57
# 34942                    -52
# 34943                    -50
# 34944                    -47
#
# [34945 rows x 4 columns]

# %%
comp_df.set_index('DATETIME', inplace=True)

# %% [markdown]
# ## Hourly data comparsion of Predicted SCADA Load with Actual SCADA Load

# %%
comp_df.index = pd.to_datetime(comp_df.index)

comp_df['ACTUAL SCADA LOAD'] = pd.to_numeric(
    comp_df['ACTUAL SCADA LOAD'], errors='coerce'
)
comp_df['PRED. SCADA LOAD'] = pd.to_numeric(
    comp_df['PRED. SCADA LOAD'], errors='coerce'
)

comp_hourly = comp_df[
    ['ACTUAL SCADA LOAD', 'PRED. SCADA LOAD']
].resample('h').mean()

plt.figure(figsize=(15, 6))
sns.lineplot(data=comp_hourly['ACTUAL SCADA LOAD'],
             label='ACTUAL SCADA LOAD')
sns.lineplot(data=comp_hourly['PRED. SCADA LOAD'],
             label='PRED. SCADA LOAD')

plt.xlabel('Month')
plt.ylabel('Load (MW)')
plt.title('Hourly Comparison of Predicted SCADA Load with Actual SCADA Load')
plt.legend()
plt.show()

# %% [markdown]
# ## Daywise comparsion of  Predicted SCADA Load with Actual SCADA Load on test data

# %%
comp_df.index = pd.to_datetime(comp_df.index)

comp_df['ACTUAL SCADA LOAD'] = pd.to_numeric(
    comp_df['ACTUAL SCADA LOAD'], errors='coerce'
)
comp_df['PRED. SCADA LOAD'] = pd.to_numeric(
    comp_df['PRED. SCADA LOAD'], errors='coerce'
)

comp_daily = comp_df[['ACTUAL SCADA LOAD',
                      'PRED. SCADA LOAD']].resample('D').mean()

plt.figure(figsize=(15, 6))

sns.lineplot(data=comp_daily['ACTUAL SCADA LOAD'],
             label='ACTUAL SCADA LOAD')

sns.lineplot(data=comp_daily['PRED. SCADA LOAD'],
             label='PRED. SCADA LOAD')

plt.xlabel('Date')
plt.ylabel('Load (MW)')
plt.title('Day-wise Comparison of Predicted SCADA Load with Actual SCADA Load')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# ## Weekly data comparsion of Predicted SCADA Load with Actual SCADA Load

# %%
comp_df.index = pd.to_datetime(comp_df.index)

comp_df['ACTUAL SCADA LOAD'] = pd.to_numeric(
    comp_df['ACTUAL SCADA LOAD'], errors='coerce'
)

comp_df['PRED. SCADA LOAD'] = pd.to_numeric(
    comp_df['PRED. SCADA LOAD'], errors='coerce'
)

comp_weekly = comp_df[
    ['ACTUAL SCADA LOAD', 'PRED. SCADA LOAD']
].resample('W').mean()

plt.figure(figsize=(15, 6))

sns.lineplot(
    data=comp_weekly['ACTUAL SCADA LOAD'],
    label='ACTUAL SCADA LOAD'
)

sns.lineplot(
    data=comp_weekly['PRED. SCADA LOAD'],
    label='PRED. SCADA LOAD'
)

plt.xlabel('Week')
plt.ylabel('Load (MW)')
plt.title('Weekly Comparison of Predicted SCADA Load with Actual SCADA Load')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# ## Over and Under Predicted SCADA Load as per actual SCADA Load

# %%
fig, ax = plt.subplots(figsize=(15, 7))

od_df = comp_df[comp_df['OD/UD PRED. SCADA LOAD'].astype(int) >= 0]
ud_df = comp_df[comp_df['OD/UD PRED. SCADA LOAD'].astype(int) < 0]

green_colors = ['g' for _ in od_df.index]
red_colors = ['r' for _ in ud_df.index]

ax.bar(od_df.index, od_df['OD/UD PRED. SCADA LOAD'].astype(int), color=green_colors, label='Over Pred. Load')
ax.bar(ud_df.index, ud_df['OD/UD PRED. SCADA LOAD'].astype(int), color=red_colors, label='Under Pred. Load')

ax.set_title('Over/Under Predicted SCADA Load as per actual SCADA Load')
ax.set_xlabel('Month')
ax.set_ylabel('Load (MW)')
ax.axhline(y=0, color='black', linestyle='--')
ax.legend(loc='upper right')

fig.tight_layout()
plt.show()

# %% [markdown]
# # Evaluation Metrics

# %%
def mean_absolute_percentage_error(test, pred, epsilon=1e-8):
    return np.mean(np.abs((test - pred) / (test + epsilon))) * 100

def forecasting_absolute_deviation_index(dataset):
    length_of_dataset = len(dataset)
    sum_of_value = sum(dataset)
    mean = sum_of_value / length_of_dataset
    deviations = [abs(num - mean) for num in dataset]
    return sum(deviations) / len(deviations)

# %% [markdown]
# #### 1. Mean Squared Error

# %%
mse = MeanSquaredError()
mse.update_state(y_test, y_pred)
mse_result = mse.result().numpy()

# %% [markdown]
# #### 2. Mean Absolute Error

# %%
mae = MeanAbsoluteError()
mae.update_state(y_test, y_pred)
mae_result = mae.result().numpy()

# %% [markdown]
# #### 3. Root Mean Squared Error

# %%
rmse = RootMeanSquaredError()
rmse.update_state(y_test, y_pred)
rmse_result = rmse.result().numpy()

# %% [markdown]
# #### 4. R2 Score

# %%
r2_result = r2_score(y_test, y_pred) * 100

# %% [markdown]
# #### 5. Mean Absolute Precentage Error

# %%
mape_result = mean_absolute_percentage_error(y_test_actual, y_test_predict)

# %% [markdown]
# #### 6. Forecasting Absolute Deviation Index (FADI)

# %%
comp_df = comp_df.astype(int)
dataset = list(comp_df['OD/UD PRED. SCADA LOAD'])

# %%
fadi_result = forecasting_absolute_deviation_index(dataset)

# %% [markdown]
# # Summary

# %%
col_name = ['', 'MSE', 'MAE', 'RMSE', 'R2', 'MAPE', 'FADI']
metrics = ['', mse_result, mae_result, rmse_result, r2_result, mape_result, fadi_result]

metrics_table = pd.DataFrame([metrics], columns=col_name)
metrics_table = metrics_table.set_index([''])
metrics_table.style.set_caption('Model Performance on 3 Years BRPL Load Data')
# Out:
# <style type="text/css">
# </style>
# <table id="T_789df">
#   <caption>Model Performance on 3 Years BRPL Load Data</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_789df_level0_col0" class="col_heading level0 col0" >MSE</th>
#       <th id="T_789df_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_789df_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_789df_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_789df_level0_col4" class="col_heading level0 col4" >MAPE</th>
#       <th id="T_789df_level0_col5" class="col_heading level0 col5" >FADI</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_789df_level0_row0" class="row_heading level0 row0" ></th>
#       <td id="T_789df_row0_col0" class="data row0 col0" >0.003700</td>
#       <td id="T_789df_row0_col1" class="data row0 col1" >0.054493</td>
#       <td id="T_789df_row0_col2" class="data row0 col2" >0.060826</td>
#       <td id="T_789df_row0_col3" class="data row0 col3" >90.698458</td>
#       <td id="T_789df_row0_col4" class="data row0 col4" >10.103255</td>
#       <td id="T_789df_row0_col5" class="data row0 col5" >82.381474</td>
#     </tr>
#   </tbody>
# </table>
